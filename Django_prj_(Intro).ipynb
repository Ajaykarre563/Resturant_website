# %% [markdown]
# # **Installation commands:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **how to create Migrations?**

# %% [markdown]
# In Django, migrations help update your database when you change your models

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **superuser**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **pswd:suresh@123**
